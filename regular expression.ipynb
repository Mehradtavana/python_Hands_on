# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehradtavana/python_Hands_on/blob/main/regular%20expression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
s = 'ac'
re.search('[acd]',s)
# Out:
# <re.Match object; span=(0, 1), match='a'>
