# %% [markdown]
# <a href="https://colab.research.google.com/github/Mehradtavana/python_Hands_on/blob/main/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a, b, c = str('Mehrad'), int(1), float(1.5)
print(f'variable a is :{type(a)}')
print(f'variable b is :{type(b)}')
print(f'variable c is :{type(c)}')

a, b = b, a


def string_length(str1):
    count = 0
    for i in str1:
        count += 1
    return count


def name_place(place):
    if place == 'school':
        name = 'john'
    elif place == 'colledge':
        name = 'Max'
    elif place == 'work':
        name = 'peter'
    else:
        name = 'Not Sure!'
    return name


def phone_name(name, phone):
    global phoneno
    phoneno[name] = phone
    return phone


distance1= 162 # houston to austin
distance2= 195 # austin to dallas
average_speed = 70
time_h = (distance1+distance2) // 70
time_min = ((distance1+distance2) % 70)*60 // 70
print(f'Total time is: {time_h} hours and {time_min} minutes')


def area_triangle(a, b, c):
    p = (a+b+c)/2
    return (p*(p-a)*(p-b)*(p-c))**0.5


n = int(input("Please put 'int' number:"))
l1 = [10, 977, 168, 106, 625, 423, 347, 387, 429, 223, 56, 185, 720, 697, 955, 564, 673, 124, 405, 718]
if n > 1000:
    print("Invalid")
elif (n%2 == 1 and n not in l1) or (n%2 == 0 and n in l1):
    print("Great")
elif (n%2 == 1 and n in l1) or (n%2 == 0 and n not in l1):
    print("Not Great")

dic = {'Ali':26, 'Mohammad':40,'Sara':35,'Danial':34.5,'Steve':60,'Anna':36,'Maryam':82,'Mahan':31,'John':91
       ,'Jonson':39,'Mehrana':96,'Tabasom':68}
for keys, value in dic.items():
    if value >= 35:
        print(keys)

failed = []
passed = []
Top = []
for keys, value in dic.items():
    if value < 35:
        failed.append(keys)
    else:
        passed.append(keys)
        if value >= 90:
            Top.append(keys)
print(f'list of failed students: {failed}')
print(f'list of top students: {Top}')


def check_overlap(list1,list2):
    for item in list1:
        if item in list2:
            print("overlapping")
        else:
            print("not overlapping")

l1 = [8,2,3,6,1,5]
def check_price(total_amt, candies_l):
    Sum = 0
    count = 0
    for p in candies_l:
        Sum += p
        if Sum <= total_amt:
            count += 1
            if count == len(candies_l):
                remain_money = total_amt - Sum
                print(f"All items!! and remain money is: {remain_money}$")
            continue
        else:
            print(f"The number of items can by based on order of list is: {count}")
            break


day = input("Please put day:")
month = input("Please put month: (like 01)")
year = input("Please put year: (like 1999)")
print(f"Entered Date:{day}/{month}/{year}")

x = 'python is good'
def capitalize_first_of_each_word(sentence):
    splited = sentence.split(" ")
    l1 = []
    for item in splited:
        item = item.capitalize()
        l1.append(item)
    final = " ".join(l1)
    print(f'The result is: {final}')

def cap(sentence):
    for item in sentence.split():
        sentence = sentence.replace(item, item.capitalize())
    print(sentence)

def mutable_string(sentence, add_word):
    l1 = sentence.split(" ")
    l1.append(add_word)
    new_string = " ".join(l1)
    return new_string

string = input("Enter the string: ")
index = int(input("Enter the change index: "))
char = input("Enter the wanted char: ")
l = list(string)
l[index] = char
string = ''.join(l)
print(string)

def count_alpha_digit(string):
    count_alpha, count_digit, count_s = 0, 0, 0
    for item in string:
        if item.isalpha():
            count_alpha += 1
        elif item.isdigit():
            count_digit += 1
        else:
            count_s += 1
    return f'The count of alpha: {count_alpha}, the count of digit: {count_digit} and the count of something else: {count_s}'


string = 'abcdefghijklmnopqrstuvwxyz'
count_char = 0
for item in string:
    if item == 'o':
        continue
    elif item == 'q':
        break
    else:
        count_char += 1
print(f'the count of char that count is: {count_char}')


user_no = input("Please write int number:")
n, number, Sum = len(user_no), int(user_no), 0
for _ in range(n):
    temp = number % 10
    Sum += temp ** n
    number //= 10
if str(Sum) == user_no:
    print('It is an Armstrong number')
else:
    print('It is not an Armstrong number')


def age_of_employee(yyyy, mm, dd):
    '''importing the date of employee was brid and calculate with today'''
    from datetime import date
    brithdate = date(yyyy, mm, dd)
    Today = date.today()
    age = Today.year-brithdate.year-((Today.month, Today.day)<(brithdate.month, brithdate.day))
    '''It check the current year is touched the day of brithday or not, if no it is minus one year
    but if yes it is not minus one year'''
    return f'employee age: {age} years'


def allsundays(year):
    from datetime import date, timedelta
    d = date(year, 1, 1)                    # January 1st
    d += timedelta(days = 6 - d.weekday())  # First Sunday
    while d.year == year:
       yield d
       d += timedelta(days = 7)

def Income_for_Sunday(year, each_session_price):
    count_sunday = 0
    for _ in allsundays(year):
        count_sunday += 1
    return f'Income from Sunday in {year} year is: {count_sunday*each_session_price}'


from datetime import date, timedelta
Today = date.today()
deadline = Today + timedelta(days=38)
meeting = Today + timedelta(weeks=6)

# %%
x = 'python is good'
def capitalize_first_of_each_word(sentence):
    splited = sentence.split(" ")
    l1 = []
    for item in splited:
        item = item.capitalize()
        l1.append(item)
    final = " ".join(l1)
    print(f'The result is: {final}')

capitalize_first_of_each_word(x)
# Out:
# The result is: Python Is Good
